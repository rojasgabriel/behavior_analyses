# %%
import pandas as pd
GRB032 = pd.read_hdf('/Users/gabriel/Desktop/DAT-KO_OFT-GRB-2024-04-20/videos/GRB032DLC_snapshot-1000.h5')['DLC_snapshot-1000']
GRB033 = pd.read_hdf('/Users/gabriel/Desktop/DAT-KO_OFT-GRB-2024-04-20/videos/GRB033DLC_snapshot-1000.h5')['DLC_snapshot-1000']
RS001 = pd.read_hdf('/Users/gabriel/Desktop/DAT-KO_OFT-GRB-2024-04-20/videos/RS001DLC_snapshot-1000.h5')['DLC_snapshot-1000']
RS002 = pd.read_hdf('/Users/gabriel/Desktop/DAT-KO_OFT-GRB-2024-04-20/videos/RS002DLC_snapshot-1000.h5')['DLC_snapshot-1000']

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(2,2, figsize=(12,5))
ax[0,0].plot(np.array(GRB032['mouse_center']['likelihood']))
ax[0,1].plot(np.array(GRB033['mouse_center']['likelihood']))
ax[1,0].plot(np.array(RS001['mouse_center']['likelihood']))
ax[1,1].plot(np.array(RS002['mouse_center']['likelihood']))

fig.suptitle('Likelihood for mouse_center')
plt.tight_layout()
plt.show()

# %%
pixels_per_cm = 9.02
np.array(GRB032['mouse_center']['x'])*pixels_per_cm
# Out:
# array([ 937.87305057,  921.59060093,  920.23130791, ..., 3606.35542326,
#        3602.34802605, 3589.72037434])

# %%
fig, ax = plt.subplots(2,2, figsize=(5,5))
ax[0,0].plot(np.array(GRB032['mouse_center']['x']), np.array(GRB032['mouse_center']['y']), linewidth=0.4, color='k', alpha=1)
ax[0,1].plot(np.array(GRB033['mouse_center']['x']), np.array(GRB033['mouse_center']['y']), linewidth=0.4, color='k', alpha=1)
ax[1,0].plot(np.array(RS001['mouse_center']['x']), np.array(RS001['mouse_center']['y']), linewidth=0.4, color='k', alpha=1)
ax[1,1].plot(np.array(RS002['mouse_center']['x']), np.array(RS002['mouse_center']['y']), linewidth=0.4, color='k', alpha=1)

plt.tight_layout()
plt.show()

# %%
min(x)
# Out:
# 75.69275581395348
